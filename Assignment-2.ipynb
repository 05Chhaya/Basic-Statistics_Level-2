# %% [markdown]
# # Set+1

# %% [markdown]
# ## Q1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
name=('Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Sun Microsystems','US Airways','Warner-Lambert')

# %%
colors = sns.color_palette('pastel')
plt.pie(df, labels = name, colors = colors, autopct='%.0f%%')
plt.show()

# %%
sns.boxplot(df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
np.mean(df)
# Out:
# 33.27133333333333

# %%
np.std(df)
# Out:
# 16.370812590976932

# %%
np.var(df)
# Out:
# 268.00350488888887

# %% [markdown]
# # Set+2

# %% [markdown]
# ## Q1

# %%
from scipy import stats

# %%
1-stats.norm.cdf(50,loc=45,scale=8)
# Out:
# 0.26598552904870054

# %% [markdown]
# ## Q2

# %%
1-stats.norm.cdf(44,loc=38,scale=6)
# Out:
# 0.15865525393145707

# %%
1-stats.norm.cdf(36,loc=38,scale=6)
# Out:
# 0.6305586598182363

# %% [markdown]
# # Q4

# %%
stats.norm.ppf(0.995,loc=100,scale=20)
# Out:
# 151.516586070978

# %%
stats.norm.ppf(0.005,loc=100,scale=20)
# Out:
# 48.483413929021985

# %% [markdown]
# # Q5

# %%
stats.norm.interval(0.975,loc=5*45,scale=3)
# Out:
# (218.27579181718517, 231.72420818281483)

# %%
stats.norm.interval(0.975,loc=7*45,scale=4)
# Out:
# (306.0343890895802, 323.9656109104198)

# %%
stats.norm.interval(0.975,loc=5*45,scale=3)+stats.norm.interval(0.975,loc=7*45,scale=4)
# Out:
# (218.27579181718517, 231.72420818281483, 306.0343890895802, 323.9656109104198)

# %%
stats.norm.ppf(0.05,loc=5*45,scale=3)
# Out:
# 220.0654391191456

# %%
stats.norm.ppf(0.05,loc=7*45,scale=4)
# Out:
# 308.4205854921941

# %% [markdown]
# # Set+4

# %% [markdown]
# ## Q3

# %%
# When x=45
Z=(45-50)/(40/100**0.5)
Z
# Out:
# -1.25

# %%
#When x=55
Z=(55-50)/(40/100**0.5)
Z
# Out:
# 1.25

# %%
stats.norm.cdf(1.25)-stats.norm.cdf(-1.25)
# Out:
# 0.7887004526662893

# %%
1-0.7887004526662893
# Out:
# 0.2112995473337107
